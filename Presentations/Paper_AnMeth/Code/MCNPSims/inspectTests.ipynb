# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
sims = pd.read_pickle("tests.pkl")

# %%
sims
# Out:
#                        label elem                          chem_function_name  \
# 0                          C    C              soil_characteristic_function_C
# 1                          H    H              soil_characteristic_function_H
# 2                          O    O              soil_characteristic_function_O
# 3                         Si   Si             soil_characteristic_function_Si
# 4                         Na   Na             soil_characteristic_function_Na
# ...                      ...  ...                                         ...
# 1308   MMica_D1p59_C0p8_H0p0  NaN  material_to_carbon_mechanical_mix_Mica_0p8
# 1309  MMica_D1p59_C0p8_H0p05  NaN  material_to_carbon_mechanical_mix_Mica_0p8
# 1310   MMica_D1p59_C0p8_H0p1  NaN  material_to_carbon_mechanical_mix_Mica_0p8
# 1311  MMica_D1p59_C0p8_H0p15  NaN  material_to_carbon_mechanical_mix_Mica_0p8
# 1312   MMica_D1p59_C0p8_H0p2  NaN  material_to_carbon_mechanical_mix_Mica_0p8
#
# ...

# %%
sims['soil_info'].iloc[0]['elements'][0]
# Out:
# array([1., 0., 0., 0., 0., 0., 0.])
